# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
dataset=pd.read_excel("Golden_view.xlsx")
dataset
# Out:
#       Days to Ship (Actual)  Days to Ship (Scheduled)  Profit per Customer  \
# 0                         4                         6                   40
# 1                         4                         6                    0
# 2                         4                         6                   16
# 3                         4                         6                   13
# 4                         4                         6                   74
# ...                     ...                       ...                  ...
# 9995                      4                         6                   -7
# 9996                      4                         6                 -527
# 9997                      6                         6                  144
# 9998                      6                         6                 1439
# 9999                      4                         6                   66
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Days to Ship (Actual)     10000 non-null  int64
#  1   Days to Ship (Scheduled)  10000 non-null  int64
#  2   Profit per Customer       10000 non-null  int64
#  3   Profit per Order          10000 non-null  float64
#  4   Sales Forecast            10000 non-null  int64
#  5   Sales per Customer        10000 non-null  float64
#  6   Units Estimate            10000 non-null  int64
#  7   Ship Status               10000 non-null  object
#  8   Profit Ratio              10000 non-null  float64
#  9   Category                  10000 non-null  object
#  10  City                      10000 non-null  object
#  11  Country                   10000 non-null  object
#  12  Customer Name             10000 non-null  object
# ...

# %%
dataset.describe()
# Out:
#        Days to Ship (Actual)  Days to Ship (Scheduled)  Profit per Customer  \
# count           10000.000000              10000.000000         10000.000000
# mean                4.006000                  4.370600            37.291300
# std                 1.743866                  2.148608           178.100194
# min                 0.000000                  0.000000         -3060.000000
# 25%                 3.000000                  3.000000             1.000000
# 50%                 4.000000                  6.000000            14.000000
# 75%                 5.000000                  6.000000            48.250000
# max                 8.000000                  6.000000          3979.000000
#
#        Profit per Order  Sales Forecast  Sales per Customer  Units Estimate  \
# count      10000.000000    10000.000000        10000.000000    10000.000000
# mean          37.282886      385.004400          293.809138        5.043000
# ...

# %%
dataset.isnull().sum()
# Out:
# Days to Ship (Actual)       0
# Days to Ship (Scheduled)    0
# Profit per Customer         0
# Profit per Order            0
# Sales Forecast              0
# Sales per Customer          0
# Units Estimate              0
# Ship Status                 0
# Profit Ratio                0
# Category                    0
# City                        0
# Country                     0
# Customer Name               0
# Discount                    0
# Number of Records           0
# Order Date                  0
# Order ID                    0
# Manufacturer                0
# Product Name                0
# Profit                      0
# Quantity                    0
# Region                      0
# Sales                       0
# Segment                     0
# Ship Date                   0
# Ship Mode                   0
# State                       0
# Sub-Category                0
# dtype: int64

# %%
dataset.groupby("Country")[["Sales"]].sum()
# Out:
#                  Sales
# Country
# Austria          81168
# Belgium          49233
# Denmark           8643
# Finland          20702
# France          858930
# Germany         628857
# Ireland          16638
# Italy           289717
# Netherlands      77520
# Norway           20529
# Portugal         15106
# Spain           287162
# Sweden           30490
# Switzerland      24874
# United Kingdom  528570

# %%
dataset.loc[dataset["Country"]=="Italy"].Sales.sum()
# Out:
# 289717

# %%
dataset.loc[dataset["Country"]=="Italy"].count()
# Out:
# Days to Ship (Actual)       1108
# Days to Ship (Scheduled)    1108
# Profit per Customer         1108
# Profit per Order            1108
# Sales Forecast              1108
# Sales per Customer          1108
# Units Estimate              1108
# Ship Status                 1108
# Profit Ratio                1108
# Category                    1108
# City                        1108
# Country                     1108
# Customer Name               1108
# Discount                    1108
# Number of Records           1108
# Order Date                  1108
# Order ID                    1108
# Manufacturer                1108
# Product Name                1108
# Profit                      1108
# Quantity                    1108
# Region                      1108
# Sales                       1108
# Segment                     1108
# Ship Date                   1108
# Ship Mode                   1108
# State                       1108
# Sub-Category                1108
# dtype: int64

# %%
pd.crosstab(index=dataset["Country"],columns=dataset["Category"])
# Out:
# Category        Furniture  Office Supplies  Technology
# Country
# Austria                41              180          49
# Belgium                23              104          20
# Denmark                 9               42          14
# Finland                16               38          10
# France                420             1854         553
# Germany               318             1348         399
# Ireland                13               72          21
# Italy                 155              746         207
# Netherlands            81              274          80
# Norway                  6               46          18
# Portugal               10               47          13
# Spain                 138              560         161
# Sweden                 36              133          34
# Switzerland            11               54          13
# United Kingdom        224             1091         318

# %%
sns.countplot(x="Region",hue="Ship Mode",data=dataset)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.barplot(x="Category",y="Sales",data=dataset)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.boxplot(x="Sub-Category",y="Sales",data=dataset)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
sns.barplot(x="Sub-Category",y="Sales",hue="Category",data=dataset)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>
